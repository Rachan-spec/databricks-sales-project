# %%
from pyspark.sql import functions as F
data = [
    (1, "Laptop", 2, 50000),
    (2, "Tablet", 3, 30000),
    (3, "Mobile", 1, 20000),
    (4, "Laptop", 3, 50000),
]

columns = ["id", "product", "country", "sales"]
df = spark.createDataFrame(data, columns)
result = df.withColumn("Tax",F.col("amount") * 0.11)
display(result)
