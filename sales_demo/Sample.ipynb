# %%
dbutils.widgets.text("country","India")
dbutils.widgets.text("min_sales","20000")

# %%
#Read the Paremeters
country = dbutils.widgets.get("country")
min_sales = int(dbutils.widgets.get("min_sales"))
print("Country",country)
print("Min Sales",min_sales)
#read the data

# %%
data =[
    (1,"Laptop","India",5000),
    (2,"Hedaphone","India",2000),
    (3,"watch","Usa",4000),
    (4,"Laptop","Usa",5000),
    (5,"Laptop","India",10000),
    (6,"Hedaphone","India",2000),
    (7,"watch","Usa",4000),
    (8,"Laptop","Usa",5000),]
columns = ["id","product","country","sales"]
df = spark.createDataFrame(data,columns)
display(df)
#
